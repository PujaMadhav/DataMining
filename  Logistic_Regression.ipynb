# %% [markdown]
# Logistic Regression:

# %%
# This code appears in every demonstration Notebook.
# By default, when you run each cell, only the last output of the codes will show.
# This code makes all outputs of a cell show.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import all the packages

# %%
default = pd.read_csv('Default.csv') # read the dataset

# %%
default.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   default  10000 non-null  object
#  1   student  10000 non-null  object
#  2   balance  10000 non-null  float64
#  3   income   10000 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 312.6+ KB

# %%
default.head()
# Out:
#   default student      balance        income
# 0      No      No   729.526495  44361.625074
# 1      No     Yes   817.180407  12106.134700
# 2      No      No  1073.549164  31767.138947
# 3      No      No   529.250605  35704.493935
# 4      No      No   785.655883  38463.495879

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='balance', y='income', hue='default', data=default, palette='viridis', alpha=0.7)
plt.title('Scatterplot of Balance vs. Income')
plt.xlabel('Balance')
plt.ylabel('Income')
plt.grid(True)
plt.show()
# Out:
# <Axes: xlabel='balance', ylabel='income'>
# Text(0.5, 1.0, 'Scatterplot of Balance vs. Income')
# Text(0.5, 0, 'Balance')
# Text(0, 0.5, 'Income')
