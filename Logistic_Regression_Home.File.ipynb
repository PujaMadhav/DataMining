# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
# import the necessary packages

# %%
default = pd.read_csv("Default.csv")

# %%
default.head(10)
# Out:
#   default student      balance        income
# 0      No      No   729.526495  44361.625074
# 1      No     Yes   817.180407  12106.134700
# 2      No      No  1073.549164  31767.138947
# 3      No      No   529.250605  35704.493935
# 4      No      No   785.655883  38463.495879
# 5      No     Yes   919.588530   7491.558572
# 6      No      No   825.513331  24905.226578
# 7      No     Yes   808.667504  17600.451344
# 8      No      No  1161.057854  37468.529288
# 9      No      No     0.000000  29275.268293

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='income', y='student', hue='default', data=default, palette='viridis', alpha=0.7)
plt.title('Scatterplot of Income vs. Default')
plt.xlabel('Income')
plt.ylabel('Default')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(default[['income']], default.student, test_size=0.2)

# %%
len(X_train)
# Out:
# 8000

# %%
len(X_test)
# Out:
# 2000

# %%
X_train
# Out:
#             income
# 5934  10516.869718
# 1510  46416.945584
# 9890  24192.888991
# 5931  47449.624238
# 6178  16957.648764
# ...            ...
# 9921  17546.997016
# 7930  17198.983559
# 9689  31039.002004
# 8577  37542.580339
# 616   27604.079271
#
# [8000 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_train
# Out:
# 5934    Yes
# 1510     No
# 9890    Yes
# 5931     No
# 6178    Yes
#        ...
# 9921    Yes
# 7930     No
# 9689     No
# 8577     No
# 616      No
# Name: student, Length: 8000, dtype: object

# %%
y_test
# Out:
# 8006     No
# 5460     No
# 4102     No
# 9054    Yes
# 1512    Yes
#        ...
# 9602     No
# 4380     No
# 7001    Yes
# 5964    Yes
# 9802     No
# Name: student, Length: 2000, dtype: object

# %%
model.predict(X_test)
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
model.score(X_test, y_test)
# Out:
# 0.702

# %%
model.predict_proba(X_test)
# Out:
# array([[0.87884201, 0.12115799],
#        [0.86361935, 0.13638065],
#        [0.86261117, 0.13738883],
#        ...,
#        [0.74957127, 0.25042873],
#        [0.73516907, 0.26483093],
#        [0.61583387, 0.38416613]])

# %%
model.predict(50000)
# Out:
# /Users/pujamadhav/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 model.predict(50000)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_base.py:451, in LinearClassifierMixin.predict(self, X)
#     437 """
#     438 Predict class labels for samples in X.
#     439
#    (...)
#     448     Vector containing the class labels for each sample.
#     449 """
#     450 xp, _ = get_namespace(X)
# --> 451 scores = self.decision_function(X)
#     452 if len(scores.shape) == 1:
#     453     indices = xp.astype(scores > 0, int)
#
# ...
